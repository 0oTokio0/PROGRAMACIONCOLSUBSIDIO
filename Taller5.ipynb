# %%
def mostrarnombre (nombres):
  print("Su nombre es " +nombres)

def mostraridentificacion (numero_identificacion):
  print("su identificación es: "+numero_identificacion)

def mostrarestado (estado_civil):
  print("Su estado civil es: "+estado_civil)

def mostrarhijos (numero_hijos):
  print("Su numero de hijos es: "+numero_hijos)  

##numero_identificacion = "10222222222 "
##print(numero_identificacion)
##nombres = "Carlos Mauricio"
##print(nombres)
##apellidos = "Quintero"
#print(apellidos)
#direccion = "carrera 7 # 76-52"
#print(direccion)
#telefono = "TEL. 113-456 789"
#print(telefono)
#edad = "Edad 34"
#print(edad)
#estado_civil = "Estado Civil: Union libre"
#print(estado_civil)
#numero_hijos = "Numero de hijos: 1"
#print(numero_hijos)
#estatura_cm = "Estatura: 1.75"
#print(estatura_cm)
#fecha_contrato = "Fecha de contratación: (19/07/2014)"
#print(fecha_contrato)
#Sueldo = "Sueldo: 3'500.000"
#print(Sueldo)
#dias_laborados = "Dias laborados: 1745"
#print(dias_laborados)

resp="Si"
while resp =="Si" or resp=="s":
  nombres=input("Digite su nombre: ")
  mostrarnombre (nombres)

  numero_identificacion=input("Digite su identificación: ")
  mostraridentificacion (numero_identificacion)

  estado_civil=input("Digite su estado civil: ")
  mostrarestado (estado_civil)

  numero_hijos=input("Digite numero de hijos: ")
  mostrarhijos (numero_hijos)

  resp= input("Desea ingresar mas informacion? ")
# Out:
# Digite su nombre: Cindy
# Su nombre es Cindy
# Digite su identificación: 1022380303
# su identificación es: 1022380303
# Digite su estado civil: Aburrida
# Su estado civil es: Aburrida
# Digite numero de hijos: 1
# Su numero de hijos es: 1
# Desea ingresar mas informacion?b
