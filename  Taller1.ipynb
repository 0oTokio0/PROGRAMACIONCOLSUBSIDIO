# %%
numero_identificacion = "Numero de identificación: 10222222222 "
print(numero_identificacion)
nombres = "Carlos Mauricio"
print(nombres)
apellidos = "Quintero"
print(apellidos)
direccion = "carrera 7 # 76-52"
print(direccion)
telefono = "TEL. 113-456 789"
print(telefono)
edad = "Edad 34"
print(edad)
estado_civil = "Estado Civil: Union libre"
print(estado_civil)
numero_hijos = "Numero de hijos: 1"
print(numero_hijos)
estatura_cm = "Estatura: 1.75"
print(estatura_cm)
fecha_contrato = "Fecha de contratación: (19/07/2014)"
print(fecha_contrato)
Sueldo = "Sueldo: 3'500.000"
print(Sueldo)
dias_laborados = "Dias laborados: 1745"
print(dias_laborados)
# Out:
# Numero de identificación: 10222222222
# Carlos Mauricio
# Quintero
# carrera 7 # 76-52
# TEL. 113-456 789
# Edad 34
# Estado Civil: Union libre
# Numero de hijos: 1
# Estatura: 1.75
# Fecha de contratación: (19/07/2014)
# Sueldo: 3'500.000
# Dias laborados: 1745
